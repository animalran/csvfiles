# %% [markdown]
# <a href="https://colab.research.google.com/github/animalran/csvfiles/blob/master/Automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
# !pip install kiteconnect
# !pip install yfinance
# Out:
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
# Requirement already satisfied: kiteconnect in /usr/local/lib/python3.6/dist-packages (3.8.2)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from kiteconnect) (2.23.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from kiteconnect) (1.12.0)
# Requirement already satisfied: pyOpenSSL>=17.5.0 in /usr/local/lib/python3.6/dist-packages (from kiteconnect) (19.1.0)
# Requirement already satisfied: enum34>=1.1.6 in /usr/local/lib/python3.6/dist-packages (from kiteconnect) (1.1.10)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from kiteconnect) (2.8.1)
# Requirement already satisfied: autobahn[twisted]>=17.10.1 in /usr/local/lib/python3.6/dist-packages (from kiteconnect) (20.7.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->kiteconnect) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->kiteconnect) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->kiteconnect) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->kiteconnect) (2.10)
# Requirement already satisfied: cryptography>=2.8 in /usr/local/lib/python3.6/dist-packages (from pyOpenSSL>=17.5.0->kiteconnect) (3.0)
# Requirement already satisfied: txaio>=20.3.1 in /usr/local/lib/python3.6/dist-packages (from autobahn[twisted]>=17.10.1->kiteconnect) (20.4.1)
# Requirement already satisfied: attrs>=19.2.0; extra == "twisted" in /usr/local/lib/python3.6/dist-packages (from autobahn[twisted]>=17.10.1->kiteconnect) (19.3.0)
# Requirement already satisfied: zope.interface>=3.6.0; extra == "twisted" in /usr/local/lib/python3.6/dist-packages (from autobahn[twisted]>=17.10.1->kiteconnect) (5.1.0)
# Requirement already satisfied: twisted>=20.3.0; extra == "twisted" in /usr/local/lib/python3.6/dist-packages (from autobahn[twisted]>=17.10.1->kiteconnect) (20.3.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.8->pyOpenSSL>=17.5.0->kiteconnect) (1.14.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from zope.interface>=3.6.0; extra == "twisted"->autobahn[twisted]>=17.10.1->kiteconnect) (49.1.0)
# Requirement already satisfied: incremental>=16.10.1 in /usr/local/lib/python3.6/dist-packages (from twisted>=20.3.0; extra == "twisted"->autobahn[twisted]>=17.10.1->kiteconnect) (17.5.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.6/dist-packages (from twisted>=20.3.0; extra == "twisted"->autobahn[twisted]>=17.10.1->kiteconnect) (19.0.0)
# Requirement already satisfied: Automat>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from twisted>=20.3.0; extra == "twisted"->autobahn[twisted]>=17.10.1->kiteconnect) (20.2.0)
# Requirement already satisfied: PyHamcrest!=1.10.0,>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from twisted>=20.3.0; extra == "twisted"->autobahn[twisted]>=17.10.1->kiteconnect) (2.0.2)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.6/dist-packages (from twisted>=20.3.0; extra == "twisted"->autobahn[twisted]>=17.10.1->kiteconnect) (15.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.8->pyOpenSSL>=17.5.0->kiteconnect) (2.20)
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
# Requirement already satisfied: yfinance in /usr/local/lib/python3.6/dist-packages (0.1.54)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.6/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.0.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.18.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.12.0)
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6

# %%
# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/libta-lib0_0.4.0-oneiric1_amd64.deb -qO libta.deb
# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/ta-lib0-dev_0.4.0-oneiric1_amd64.deb -qO ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib
# Out:
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
# (Reading database ... 144491 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) over (0.4.0-oneiric1) ...
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) over (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
# Requirement already satisfied: ta-lib in /usr/local/lib/python3.6/dist-packages (0.4.18)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from ta-lib) (1.18.5)
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
#
#  NIFTY BANK
#                         open     high      low    close
# 2020-07-22 12:28:00  22882.6  22882.6  22882.6  22882.6
# 2020-07-22 12:29:00  22882.6  22882.6  22882.6  22882.6

# %%
#
from kiteconnect import KiteConnect
import yfinance as yf
import requests
import pandas as pd
import time
from kiteconnect import KiteTicker
import talib as ta
from talib import MA_Type
from talib import abstract
from talib.abstract import *
import pdb
#print(dir(KiteConnect))

# %%
#
kws=""
kite=""
api_k = "xrx73105w50h5g25"
api_s  = "4zk0dp6i1p03ji4haxrw44buh9hn5v27"
access_token="pl6LnjVCid7K1ECYz6CgKwFg7o4ue1Mt"
# request token url
#url= " https://kite.trade/connect/login?api_key=xrx73105w50h5g25"
#request_token="HyirnWb2zH2wiTv3q0PUtJeTlTOjT6C5"

kite = KiteConnect(api_key=api_k)
kite.set_access_token(access_token)

#data = kite.generate_session(request_token,api_secret=api_s)
#print(data)

# %%
def get_login(api_k,api_s):
    global kws,kite
    kite=KiteConnect(api_key=api_k)
    kite.set_access_token(access_token)
    kws = KiteTicker(api_k,access_token)
get_login(api_k,api_s)

# %%
# genetaring sma using talib and kiteticker
trd_portfolio    =  {55875591:{"name":"CRUDEOIL20AUGFUT"}}
ticks_storage   = pd.DataFrame()
timeframe   =   1
def ohlc_maker(ticks):
    for token in trd_portfolio:
        specs   = trd_portfolio[token]
        #print(specs.keys())
        name    = specs['name']
        #print(name)
        #print(ticks)
        for single_company in ticks:
            if single_company['instrument_token'] == token:

                if 'temp' not in specs.keys():
                    specs['temp']={}
                    continue

                temp= specs['temp']

                temp[single_company['timestamp']]= single_company['last_price']
                df  = pd.DataFrame.from_dict(temp, orient='index')

                ohlc= df[0].resample(str(timeframe)+'Min').ohlc()

                #print("\n",name)
                print(ohlc)

# %%
trd_portfolio    =  {55875591:{"name":"CRUDEOIL20AUGFUT"}}
ticks_storage   = pd.DataFrame()
timeframe   =   1
def ohlc_maker(ticks):
    for token in trd_portfolio:
        specs   = trd_portfolio[token]
        name    = specs['name']
        #print(specs)
        for single_company in ticks:
            if single_company['instrument_token'] == token:

                if 'temp' not in specs.keys():
                    specs['temp']={}
                    continue

                temp= specs['temp']

                temp[single_company['timestamp']]= single_company['last_price']
                df  = pd.DataFrame.from_dict(temp, orient='index')

                ohlc= df[0].resample(str(timeframe)+'Min').ohlc()

                #print("\n",name)
                print(ohlc)
def on_ticks(ws,ticks):
    ohlc_maker(ticks)

subscribe = [x for x in trd_portfolio]

def on_connect(ws,response):
    ws.subscribe(subscribe)
    ws.set_mode(ws.MODE_FULL,subscribe)

kws.on_ticks=on_ticks
kws.on_connect= on_connect
kws.connect()
# Out:
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0
#                        open    high     low   close
# 2020-07-22 13:01:00  3088.0  3088.0  3088.0  3088.0

# %%
data = kite.quote([':CRUDEOIL20AUG3800CE'])

a=kite.instruments(exchange="MCX")
a
# Out:
# [OrderedDict([('instrument_token', 56205831),
#               ('exchange_token', '219554'),
#               ('tradingsymbol', 'ALUMINIUM20AUGFUT'),
#               ('name', 'ALUMINIUM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55967751),
#               ('exchange_token', '218624'),
#               ('tradingsymbol', 'ALUMINIUM20JULFUT'),
#               ('name', 'ALUMINIUM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56587015),
#               ('exchange_token', '221043'),
#               ('tradingsymbol', 'ALUMINIUM20NOVFUT'),
#               ('name', 'ALUMINIUM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56465671),
#               ('exchange_token', '220569'),
#               ('tradingsymbol', 'ALUMINIUM20OCTFUT'),
#               ('name', 'ALUMINIUM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56385543),
#               ('exchange_token', '220256'),
#               ('tradingsymbol', 'ALUMINIUM20SEPFUT'),
#               ('name', 'ALUMINIUM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56588807),
#               ('exchange_token', '221050'),
#               ('tradingsymbol', 'ALUMINIUMAUG20SEP20FUT'),
#               ('name', 'ALUMINIUM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56509191),
#               ('exchange_token', '220739'),
#               ('tradingsymbol', 'ALUMINIUMJUL20AUG20FUT'),
#               ('name', 'ALUMINIUM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56588551),
#               ('exchange_token', '221049'),
#               ('tradingsymbol', 'ALUMINIUMJUL20SEP20FUT'),
#               ('name', 'ALUMINIUM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56064007),
#               ('exchange_token', '219000'),
#               ('tradingsymbol', 'CARDAMOM20AUGFUT'),
#               ('name', 'CARDAMOM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 14)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56728839),
#               ('exchange_token', '221597'),
#               ('tradingsymbol', 'CARDAMOM20DECFUT'),
#               ('name', 'CARDAMOM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 12, 15)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56530183),
#               ('exchange_token', '220821'),
#               ('tradingsymbol', 'CARDAMOM20NOVFUT'),
#               ('name', 'CARDAMOM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 13)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56413191),
#               ('exchange_token', '220364'),
#               ('tradingsymbol', 'CARDAMOM20OCTFUT'),
#               ('name', 'CARDAMOM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 15)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56277255),
#               ('exchange_token', '219833'),
#               ('tradingsymbol', 'CARDAMOM20SEPFUT'),
#               ('name', 'CARDAMOM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 15)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56204039),
#               ('exchange_token', '219547'),
#               ('tradingsymbol', 'CASTORSEED20AUGFUT'),
#               ('name', 'CASTORSEED'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 20)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56589831),
#               ('exchange_token', '221054'),
#               ('tradingsymbol', 'CASTORSEED20NOVFUT'),
#               ('name', 'CASTORSEED'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 20)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56467719),
#               ('exchange_token', '220577'),
#               ('tradingsymbol', 'CASTORSEED20OCTFUT'),
#               ('name', 'CASTORSEED'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 20)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56408327),
#               ('exchange_token', '220345'),
#               ('tradingsymbol', 'CASTORSEED20SEPFUT'),
#               ('name', 'CASTORSEED'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 18)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56205575),
#               ('exchange_token', '219553'),
#               ('tradingsymbol', 'COPPER20AUGFUT'),
#               ('name', 'COPPER'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55965703),
#               ('exchange_token', '218616'),
#               ('tradingsymbol', 'COPPER20JULFUT'),
#               ('name', 'COPPER'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56587271),
#               ('exchange_token', '221044'),
#               ('tradingsymbol', 'COPPER20NOVFUT'),
#               ('name', 'COPPER'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56465927),
#               ('exchange_token', '220570'),
#               ('tradingsymbol', 'COPPER20OCTFUT'),
#               ('name', 'COPPER'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56385031),
#               ('exchange_token', '220254'),
#               ('tradingsymbol', 'COPPER20SEPFUT'),
#               ('name', 'COPPER'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56591879),
#               ('exchange_token', '221062'),
#               ('tradingsymbol', 'COPPERAUG20SEP20FUT'),
#               ('name', 'COPPER'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56512263),
#               ('exchange_token', '220751'),
#               ('tradingsymbol', 'COPPERJUL20AUG20FUT'),
#               ('name', 'COPPER'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56591623),
#               ('exchange_token', '221061'),
#               ('tradingsymbol', 'COPPERJUL20SEP20FUT'),
#               ('name', 'COPPER'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55962631),
#               ('exchange_token', '218604'),
#               ('tradingsymbol', 'COTTON20AUGFUT'),
#               ('name', 'COTTON'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56406535),
#               ('exchange_token', '220338'),
#               ('tradingsymbol', 'COTTON20DECFUT'),
#               ('name', 'COTTON'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 12, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55804423),
#               ('exchange_token', '217986'),
#               ('tradingsymbol', 'COTTON20JULFUT'),
#               ('name', 'COTTON'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56406279),
#               ('exchange_token', '220337'),
#               ('tradingsymbol', 'COTTON20NOVFUT'),
#               ('name', 'COTTON'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56406023),
#               ('exchange_token', '220336'),
#               ('tradingsymbol', 'COTTON20OCTFUT'),
#               ('name', 'COTTON'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56592135),
#               ('exchange_token', '221063'),
#               ('tradingsymbol', 'COTTONAUG20OCT20FUT'),
#               ('name', 'COTTON'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56468487),
#               ('exchange_token', '220580'),
#               ('tradingsymbol', 'COTTONJUL20AUG20FUT'),
#               ('name', 'COTTON'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56591367),
#               ('exchange_token', '221060'),
#               ('tradingsymbol', 'COTTONJUL20OCT20FUT'),
#               ('name', 'COTTON'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55966215),
#               ('exchange_token', '218618'),
#               ('tradingsymbol', 'COTTONREF20AUGFUT'),
#               ('name', 'COTTONREF'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56407303),
#               ('exchange_token', '220341'),
#               ('tradingsymbol', 'COTTONREF20DECFUT'),
#               ('name', 'COTTONREF'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 12, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55804935),
#               ('exchange_token', '217988'),
#               ('tradingsymbol', 'COTTONREF20JULFUT'),
#               ('name', 'COTTONREF'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56407047),
#               ('exchange_token', '220340'),
#               ('tradingsymbol', 'COTTONREF20NOVFUT'),
#               ('name', 'COTTONREF'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56406791),
#               ('exchange_token', '220339'),
#               ('tradingsymbol', 'COTTONREF20OCTFUT'),
#               ('name', 'COTTONREF'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 10.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56204551),
#               ('exchange_token', '219549'),
#               ('tradingsymbol', 'CPO20AUGFUT'),
#               ('name', 'CPO'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55965959),
#               ('exchange_token', '218617'),
#               ('tradingsymbol', 'CPO20JULFUT'),
#               ('name', 'CPO'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56587527),
#               ('exchange_token', '221045'),
#               ('tradingsymbol', 'CPO20NOVFUT'),
#               ('name', 'CPO'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56466183),
#               ('exchange_token', '220571'),
#               ('tradingsymbol', 'CPO20OCTFUT'),
#               ('name', 'CPO'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56408071),
#               ('exchange_token', '220344'),
#               ('tradingsymbol', 'CPO20SEPFUT'),
#               ('name', 'CPO'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56592391),
#               ('exchange_token', '221064'),
#               ('tradingsymbol', 'CPOAUG20SEP20FUT'),
#               ('name', 'CPO'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56469511),
#               ('exchange_token', '220584'),
#               ('tradingsymbol', 'CPOJUL20AUG20FUT'),
#               ('name', 'CPO'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56592647),
#               ('exchange_token', '221065'),
#               ('tradingsymbol', 'CPOJUL20SEP20FUT'),
#               ('name', 'CPO'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55875591),
#               ('exchange_token', '218264'),
#               ('tradingsymbol', 'CRUDEOIL20AUGFUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 19)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56551687),
#               ('exchange_token', '220905'),
#               ('tradingsymbol', 'CRUDEOIL20DECFUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 12, 18)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56431879),
#               ('exchange_token', '220437'),
#               ('tradingsymbol', 'CRUDEOIL20NOVFUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 19)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56336903),
#               ('exchange_token', '220066'),
#               ('tradingsymbol', 'CRUDEOIL20OCTFUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 19)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56167687),
#               ('exchange_token', '219405'),
#               ('tradingsymbol', 'CRUDEOIL20SEPFUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 21)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56744455),
#               ('exchange_token', '221658'),
#               ('tradingsymbol', 'CRUDEOIL21JANFUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2021, 1, 19)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56744711),
#               ('exchange_token', '221659'),
#               ('tradingsymbol', 'CRUDEOILAUG20OCT20FUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 19)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56552199),
#               ('exchange_token', '220907'),
#               ('tradingsymbol', 'CRUDEOILAUG20SEP20FUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 19)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56744967),
#               ('exchange_token', '221660'),
#               ('tradingsymbol', 'CRUDEOILSEP20OCT20FUT'),
#               ('name', 'CRUDEOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 21)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55324679),
#               ('exchange_token', '216112'),
#               ('tradingsymbol', 'GOLD20AUGFUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55683079),
#               ('exchange_token', '217512'),
#               ('tradingsymbol', 'GOLD20DECFUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 12, 4)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55556103),
#               ('exchange_token', '217016'),
#               ('tradingsymbol', 'GOLD20OCTFUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56276999),
#               ('exchange_token', '219832'),
#               ('tradingsymbol', 'GOLD21APRFUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2021, 4, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55851015),
#               ('exchange_token', '218168'),
#               ('tradingsymbol', 'GOLD21FEBFUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2021, 2, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56530439),
#               ('exchange_token', '220822'),
#               ('tradingsymbol', 'GOLD21JUNFUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2021, 6, 4)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56512519),
#               ('exchange_token', '220752'),
#               ('tradingsymbol', 'GOLDAUG20DEC20FUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56232711),
#               ('exchange_token', '219659'),
#               ('tradingsymbol', 'GOLDAUG20OCT20FUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56386567),
#               ('exchange_token', '220260'),
#               ('tradingsymbol', 'GOLDGUINEA20AUGFUT'),
#               ('name', 'GOLDGUINEA'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56207367),
#               ('exchange_token', '219560'),
#               ('tradingsymbol', 'GOLDGUINEA20JULFUT'),
#               ('name', 'GOLDGUINEA'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56590599),
#               ('exchange_token', '221057'),
#               ('tradingsymbol', 'GOLDGUINEA20OCTFUT'),
#               ('name', 'GOLDGUINEA'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56466439),
#               ('exchange_token', '220572'),
#               ('tradingsymbol', 'GOLDGUINEA20SEPFUT'),
#               ('name', 'GOLDGUINEA'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 30)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56409351),
#               ('exchange_token', '220349'),
#               ('tradingsymbol', 'GOLDM20AUGFUT'),
#               ('name', 'GOLDM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56622599),
#               ('exchange_token', '221182'),
#               ('tradingsymbol', 'GOLDM20OCTFUT'),
#               ('name', 'GOLDM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56513031),
#               ('exchange_token', '220754'),
#               ('tradingsymbol', 'GOLDM20SEPFUT'),
#               ('name', 'GOLDM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 4)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56623367),
#               ('exchange_token', '221185'),
#               ('tradingsymbol', 'GOLDMAUG20OCT20FUT'),
#               ('name', 'GOLDM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56513543),
#               ('exchange_token', '220756'),
#               ('tradingsymbol', 'GOLDMAUG20SEP20FUT'),
#               ('name', 'GOLDM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56623623),
#               ('exchange_token', '221186'),
#               ('tradingsymbol', 'GOLDMSEP20OCT20FUT'),
#               ('name', 'GOLDM'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 4)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56512775),
#               ('exchange_token', '220753'),
#               ('tradingsymbol', 'GOLDOCT20DEC20FUT'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 5)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56386311),
#               ('exchange_token', '220259'),
#               ('tradingsymbol', 'GOLDPETAL20AUGFUT'),
#               ('name', 'GOLDPETAL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56207623),
#               ('exchange_token', '219561'),
#               ('tradingsymbol', 'GOLDPETAL20JULFUT'),
#               ('name', 'GOLDPETAL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56590855),
#               ('exchange_token', '221058'),
#               ('tradingsymbol', 'GOLDPETAL20OCTFUT'),
#               ('name', 'GOLDPETAL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56466695),
#               ('exchange_token', '220573'),
#               ('tradingsymbol', 'GOLDPETAL20SEPFUT'),
#               ('name', 'GOLDPETAL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 30)),
#               ('strike', 0.0),
#               ('tick_size', 1.0),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55597319),
#               ('exchange_token', '217177'),
#               ('tradingsymbol', 'KAPAS20NOVFUT'),
#               ('name', 'KAPAS'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56204807),
#               ('exchange_token', '219550'),
#               ('tradingsymbol', 'KAPAS21APRFUT'),
#               ('name', 'KAPAS'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2021, 4, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55804679),
#               ('exchange_token', '217987'),
#               ('tradingsymbol', 'KAPAS21FEBFUT'),
#               ('name', 'KAPAS'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2021, 2, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56205319),
#               ('exchange_token', '219552'),
#               ('tradingsymbol', 'LEAD20AUGFUT'),
#               ('name', 'LEAD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55965447),
#               ('exchange_token', '218615'),
#               ('tradingsymbol', 'LEAD20JULFUT'),
#               ('name', 'LEAD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56587783),
#               ('exchange_token', '221046'),
#               ('tradingsymbol', 'LEAD20NOVFUT'),
#               ('name', 'LEAD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56466951),
#               ('exchange_token', '220574'),
#               ('tradingsymbol', 'LEAD20OCTFUT'),
#               ('name', 'LEAD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56386055),
#               ('exchange_token', '220258'),
#               ('tradingsymbol', 'LEAD20SEPFUT'),
#               ('name', 'LEAD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56589575),
#               ('exchange_token', '221053'),
#               ('tradingsymbol', 'LEADAUG20SEP20FUT'),
#               ('name', 'LEAD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56509959),
#               ('exchange_token', '220742'),
#               ('tradingsymbol', 'LEADJUL20AUG20FUT'),
#               ('name', 'LEAD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56589063),
#               ('exchange_token', '221051'),
#               ('tradingsymbol', 'LEADJUL20SEP20FUT'),
#               ('name', 'LEAD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.05),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56249863),
#               ('exchange_token', '219726'),
#               ('tradingsymbol', 'MENTHAOIL20AUGFUT'),
#               ('name', 'MENTHAOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56589319),
#               ('exchange_token', '221052'),
#               ('tradingsymbol', 'MENTHAOIL20DECFUT'),
#               ('name', 'MENTHAOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 12, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56249607),
#               ('exchange_token', '219725'),
#               ('tradingsymbol', 'MENTHAOIL20JULFUT'),
#               ('name', 'MENTHAOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56467207),
#               ('exchange_token', '220575'),
#               ('tradingsymbol', 'MENTHAOIL20NOVFUT'),
#               ('name', 'MENTHAOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56405255),
#               ('exchange_token', '220333'),
#               ('tradingsymbol', 'MENTHAOIL20OCTFUT'),
#               ('name', 'MENTHAOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 10, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56250119),
#               ('exchange_token', '219727'),
#               ('tradingsymbol', 'MENTHAOIL20SEPFUT'),
#               ('name', 'MENTHAOIL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 30)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56465415),
#               ('exchange_token', '220568'),
#               ('tradingsymbol', 'NATURALGAS20AUGFUT'),
#               ('name', 'NATURALGAS'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56381191),
#               ('exchange_token', '220239'),
#               ('tradingsymbol', 'NATURALGAS20JULFUT'),
#               ('name', 'NATURALGAS'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 28)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56584711),
#               ('exchange_token', '221034'),
#               ('tradingsymbol', 'NATURALGAS20SEPFUT'),
#               ('name', 'NATURALGAS'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 9, 25)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 56205063),
#               ('exchange_token', '219551'),
#               ('tradingsymbol', 'NICKEL20AUGFUT'),
#               ('name', 'NICKEL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 8, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55963399),
#               ('exchange_token', '218607'),
#               ('tradingsymbol', 'NICKEL20JULFUT'),
#               ('name', 'NICKEL'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 7, 31)),
#               ('strike', 0.0),
#               ('tick_size', 0.1),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'MCX-FUT'),
# ...
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55807495),
#               ('exchange_token', '217998'),
#               ('tradingsymbol', 'GOLD20NOV39800PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 39800.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55807751),
#               ('exchange_token', '217999'),
#               ('tradingsymbol', 'GOLD20NOV39900CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 39900.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55808007),
#               ('exchange_token', '218000'),
#               ('tradingsymbol', 'GOLD20NOV39900PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 39900.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55786503),
#               ('exchange_token', '217916'),
#               ('tradingsymbol', 'GOLD20NOV40000CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40000.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55786759),
#               ('exchange_token', '217917'),
#               ('tradingsymbol', 'GOLD20NOV40000PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40000.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55787015),
#               ('exchange_token', '217918'),
#               ('tradingsymbol', 'GOLD20NOV40100CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40100.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55787271),
#               ('exchange_token', '217919'),
#               ('tradingsymbol', 'GOLD20NOV40100PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40100.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55787527),
#               ('exchange_token', '217920'),
#               ('tradingsymbol', 'GOLD20NOV40200CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40200.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55787783),
#               ('exchange_token', '217921'),
#               ('tradingsymbol', 'GOLD20NOV40200PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40200.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55788039),
#               ('exchange_token', '217922'),
#               ('tradingsymbol', 'GOLD20NOV40300CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40300.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55788295),
#               ('exchange_token', '217923'),
#               ('tradingsymbol', 'GOLD20NOV40300PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40300.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55788551),
#               ('exchange_token', '217924'),
#               ('tradingsymbol', 'GOLD20NOV40400CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40400.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55788807),
#               ('exchange_token', '217925'),
#               ('tradingsymbol', 'GOLD20NOV40400PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40400.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55789063),
#               ('exchange_token', '217926'),
#               ('tradingsymbol', 'GOLD20NOV40500CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40500.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55789319),
#               ('exchange_token', '217927'),
#               ('tradingsymbol', 'GOLD20NOV40500PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40500.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55789575),
#               ('exchange_token', '217928'),
#               ('tradingsymbol', 'GOLD20NOV40600CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40600.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55789831),
#               ('exchange_token', '217929'),
#               ('tradingsymbol', 'GOLD20NOV40600PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40600.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55790087),
#               ('exchange_token', '217930'),
#               ('tradingsymbol', 'GOLD20NOV40700CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40700.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55790343),
#               ('exchange_token', '217931'),
#               ('tradingsymbol', 'GOLD20NOV40700PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40700.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55790599),
#               ('exchange_token', '217932'),
#               ('tradingsymbol', 'GOLD20NOV40800CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40800.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55790855),
#               ('exchange_token', '217933'),
#               ('tradingsymbol', 'GOLD20NOV40800PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40800.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55791111),
#               ('exchange_token', '217934'),
#               ('tradingsymbol', 'GOLD20NOV40900CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40900.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55791367),
#               ('exchange_token', '217935'),
#               ('tradingsymbol', 'GOLD20NOV40900PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 40900.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55791623),
#               ('exchange_token', '217936'),
#               ('tradingsymbol', 'GOLD20NOV41000CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41000.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55791879),
#               ('exchange_token', '217937'),
#               ('tradingsymbol', 'GOLD20NOV41000PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41000.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55792135),
#               ('exchange_token', '217938'),
#               ('tradingsymbol', 'GOLD20NOV41100CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41100.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55792391),
#               ('exchange_token', '217939'),
#               ('tradingsymbol', 'GOLD20NOV41100PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41100.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55792647),
#               ('exchange_token', '217940'),
#               ('tradingsymbol', 'GOLD20NOV41200CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41200.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55792903),
#               ('exchange_token', '217941'),
#               ('tradingsymbol', 'GOLD20NOV41200PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41200.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55793159),
#               ('exchange_token', '217942'),
#               ('tradingsymbol', 'GOLD20NOV41300CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41300.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55793415),
#               ('exchange_token', '217943'),
#               ('tradingsymbol', 'GOLD20NOV41300PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41300.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55793671),
#               ('exchange_token', '217944'),
#               ('tradingsymbol', 'GOLD20NOV41400CE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41400.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  OrderedDict([('instrument_token', 55793927),
#               ('exchange_token', '217945'),
#               ('tradingsymbol', 'GOLD20NOV41400PE'),
#               ('name', 'GOLD'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2020, 11, 25)),
#               ('strike', 41400.0),
#               ('tick_size', 0.5),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'MCX-OPT'),
#               ('exchange', 'MCX')]),
#  ...]
