# %% [markdown]
# <a href="https://colab.research.google.com/github/animalran/csvfiles/blob/master/Nse1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Developed in Python 3.6.3
from nsetools import Nse
from pprint import pprint
import requests
import urllib
nse = Nse()
print(nse)
#index_codes = nse.get_index_list()
#pprint(index_codes)
#nifty_quote = nse.get_index_quote('NIFTY 50')
mp1=str(nse.get_index_quote("NIFTY 50")['lastPrice'])
print(mp1)
#pprint(nifty_quote)
#all_stock_codes = nse.get_stock_codes()
#pprint(all_stock_codes)
#q = nse.get_quote('infy')
def investing(x,y,z,s):
    try:
        q = nse.get_quote(str(x))
        c = str(q['companyName'])
        v = q['lastPrice']
        p = float(q['pChange'] or 0)
        #print(q)
        if v < y:
            r=str(c+' : Buy '+ '( '+str(v)+' )')
        elif p < z:
            r=str(c+' : Buy(p) '+ '( '+str(v)+' )')
        elif v > s:
            r=str(x+' : Sell '+ '( '+str(v)+' )')
        else:
            r=str('')
        return r
    except:
    #    pass
    #if q is None:
    #    r=str('NO DATA ')
    #    return r
    #else:
        #print(q)
        print('error as no quote received')

def messy(x):
    x=str(x)
    if len(x)>2:
        me = x+'\n'
    else:
        me=''
    return me
#mp2=str(investing('TATAMOTORS',325,-5,350))
mp2=str(investing('TATAMOTORS',250,-10,400))
mp3=str(investing('VEDL',150,-20,500))
mp4=str(investing('RELIANCE',650,-25,2000))
mp5=str(investing('NTPC',125,-15,500))
mp6=str(investing('NTPC',100,-25,500))
mp7=str(investing('POWERGRID',125,-15,500))
mp8=str(investing('GAIL',150,-25,500))
mp9=str(investing('IOC',100,-25,500))
mp10=str(investing('BPCL',250,-15,1000))
mp11=str(investing('PNB',75,-15,500))
mp12=str(investing('HINDZINC',117,-25,500))
mp13=str(investing('JINDALSTEL',85,-25,500))
mp14=str(investing('NMDC',75,-25,500))
mp15=str(investing('SAIL',53,-15,500))
mp16=str(investing('NATIONALUM',30,-25,500))
mp17=str(investing('TATAPOWER',51,-25,300))
mp18=str(investing('HINDPETRO',141,-45,500))
mp19=str(investing('NMDC',75,-45,300))
mp20=str(investing('BPCL',245,-45,1000))
mp21=str(investing('SUNPHARMA',435,-10,600))
mp22=str(investing('CIPLA',460,-10,1000))
mp23=str(investing('DRREDDY',1885,-10,3000))
mp24=str(investing('PEL',1500,-15,4000))
mp25=str(investing('LUPIN',750,-10,1500))
mp26=str(investing('AUROPHARMA',500,-10,1000))
mp27=str(investing('BIOCON',300,-20,1000))
mp28=str(investing('CADILAHC',300,-20,1000))
mp29=str(investing('DIVISLAB',600,-20,2000))
mp30=str(investing('GLENMARK',500,-10,1000))
mp31=str(investing('ITC',178,-35,500))
mp32=str(investing('HINDUNILVR',780,-45,2000))
mp33=str(investing('BRITANNIA',2530,-55,10000))
mp34=str(investing('GODREJCP',560,-25,2000))
mp35=str(investing('DABUR',233,-25,1000))
mp36=str(investing('MARICO',190,-25,1000))
mp37=str(investing('COLPAL',790,-25,2000))
mp38=str(investing('TATAGLOBAL',100,-45,1000))
mp39=str(investing('IGL',75,-25,1000))
mp40=str(investing('ICICIBANK',140,-55,1350))
mp41=str(investing('BAJFINANCE',1500,-45,3000))
mp42=str(investing('SBIN',150,-55,1000))
mp43=str(investing('HDFCBANK',950,-45,3000))
mp44=str(investing('KOTAKBANK',595,-55,2000))
mp45=str(investing('INDUSINDBK',1050,-55,3000))
mp46=str(investing('AXISBANK',200,-55,1000))
mp47=str(investing('YESBANK',220,-45,500))
mp48=str(investing('FEDERALBNK',42,-55,300))
mp49=str(investing('RBLBANK',275,-55,1000))
mp50=str(investing('BANKBARODA',86,-55,500))
mp51=str(investing('PNB',70,-25,500))
mp52=str(investing('HDFC',1000,-45,2000))
mp53=str(investing('IBULHSGFIN',600,-45,1440))
mp54=str(investing('SRTRANSFIN',500,-55,2000))
mp55=str(investing('BAJAJHLDNG',1750,-45,3250))
mp56=str(investing('M&MFIN',233,-45,1000))
mp57=str(investing('BHARATFIN',655,-55,2000))
mp58=str(investing('BAJAJFINSV',2500,-55,10000))
mp59=str(investing('BRIGADE',50,-65,325))
mp60=str(investing('ASHOKLEY',85,-45,700))
mp61=str(investing('PHOENIXLTD',285,-65,1000))
mp62=str(investing('GODREJPROP',285,-65,900))
mp63=str(investing('OBEROIRLTY',250,-65,600))
mp64=str(investing('IBREALEST',50,-75,270))
mp65=str(investing('DLF',100,-55,500))
#mp21=str(investing('PNB',92,-5,1000))
#mp22=str(investing('HINDZINC',308,-5,1000))
#mp23=str(investing('JINDALSTEL',219,-5,1000))
#mp24=str(investing('NMDC',115,-5,1000))
#mp24=str(investing('NMDC',115,-5,1000))

#mess=messy(mp2)+messy(mp3)+messy(mp4)+messy(mp5)+messy(mp6)+messy(mp7)+messy(mp8)+messy(mp9)+messy(mp10)+messy(mp11)+messy(mp12)+messy(mp13)+messy(mp14)+messy(mp15)+messy(mp16)+messy(mp17)+messy(mp18)+messy(mp19)+messy(mp20)+messy(mp21)+messy(mp22)+messy(mp23)+messy(mp24)+messy(mp25)+messy(mp26)+messy(mp27)+messy(mp28)+messy(mp29)+messy(mp30)+messy(mp31)+messy(mp32)+messy(mp33)+messy(mp34)+messy(mp35)+messy(mp36)+messy(mp37)+messy(mp38)+messy(mp39)
mess=messy(mp1)+messy(mp2)+messy(mp3)+messy(mp4)+messy(mp5)+messy(mp6)+messy(mp7)+messy(mp8)+messy(mp9)+messy(mp10)+messy(mp11)+messy(mp12)+messy(mp13)+messy(mp14)+messy(mp15)+messy(mp16)+messy(mp17)+messy(mp18)+messy(mp19)+messy(mp20)+messy(mp21)+messy(mp22)+messy(mp23)+messy(mp24)+messy(mp25)+messy(mp26)+messy(mp27)+messy(mp28)+messy(mp29)+messy(mp30)+messy(mp31)+messy(mp32)+messy(mp33)+messy(mp34)+messy(mp35)+messy(mp36)+messy(mp37)+messy(mp38)+messy(mp39)+messy(mp40)+messy(mp41)+messy(mp42)+messy(mp43)+messy(mp44)+messy(mp45)+messy(mp46)+messy(mp47)+messy(mp48)+messy(mp49)+messy(mp50)+messy(mp51)+messy(mp52)+messy(mp53)+messy(mp54)+messy(mp55)+messy(mp56)+messy(mp57)+messy(mp58)+messy(mp59)+messy(mp60)+messy(mp61)+messy(mp62)+messy(mp63)+messy(mp64)+messy(mp65)
print(mess)
teletext=urllib.parse.quote_plus(mess)
if len(mess)>5:
    print(mess)
    status = requests.post("https://api.telegram.org/bot457245500:AAG9c_WlaGmMseCfNSVc12-h5vwXzsT5n-o/sendMessage?chat_id=401041810&text="+teletext)
    status = requests.post("https://api.telegram.org/bot457245500:AAG9c_WlaGmMseCfNSVc12-h5vwXzsT5n-o/sendMessage?chat_id=-279566111&text="+teletext)
else:
    print('no mess created')
